# %%
import pandas as pd

# %%
df_1 = pd.read_csv('train.csv')
df_2 = pd.read_csv('test.csv')

# %%
df_com = pd.concat([df_1, df_2], ignore_index=True)

# %%
df_com
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                   0.0
# 1              1                  0.00               2                   0.0
# 2              1                  0.10               2                   0.0
# 3              1                  0.00               1                   0.0
# 4              1                  0.00               2                   0.0
# ..           ...                   ...             ...                   ...
# 691            1                  0.29               1                   0.0
# 692            1                  0.40               1                   0.0
# 693            1                  0.00               2                   0.0
# 694            0                  0.17               1                   0.0
# 695            1                  0.44               1                   0.0
#
# ...

# %%
label_col = 'fake'
features = df_com.drop(columns=[label_col])
label = df_com[label_col]

scaler = StandardScaler()
normalized_features = scaler.fit_transform(features)
df_normalized = pd.DataFrame(normalized_features, columns=features.columns)

df_normalized[label_col] = label
df_normalized.to_csv('comb_Z_score.csv', index=False)

print("완료")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 5
#       2 features = df_com.drop(columns=[label_col])
#       3 label = df_com[label_col]
# ----> 5 scaler = StandardScaler()
#       6 normalized_features = scaler.fit_transform(features)
#       7 df_normalized = pd.DataFrame(normalized_features, columns=features.columns)
#
# NameError: name 'StandardScaler' is not defined
